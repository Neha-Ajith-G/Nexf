# %%
#Import package
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
height_df = pd.read_csv('/content/drive/MyDrive/Copy of SOCR-HeightWeight.csv')

# %%
df_mean = height_df.mean()

# %%
df_median = height_df.median()

# %%
df_mode = height_df.mode()

# %%
print("mean,median,mode:",df_mean,df_median,df_mode)
# Out:
# mean,median,mode: Index             12500.500000
# Height(Inches)       67.993114
# Weight(Pounds)      127.079421
# dtype: float64 Index             12500.50000
# Height(Inches)       67.99570
# Weight(Pounds)      127.15775
# dtype: float64        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.65796        124.7975
# 1          2        67.34629             NaN
# 2          3        67.41672             NaN
# 3          4        67.94061             NaN
# 4          5        67.97769             NaN
# ...      ...             ...             ...
# 24995  24996             NaN             NaN
# 24996  24997             NaN             NaN
# 24997  24998             NaN             NaN
# 24998  24999             NaN             NaN
# 24999  25000             NaN             NaN
#
# [25000 rows x 3 columns]

# %%
# !git clone https://github.com/Neha-Ajith-G/Nexf.git
# Out:
# Cloning into 'Nexf'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
cd Nexf/
# Out:
# [Errno 2] No such file or directory: 'Nexf/'
# /content/Nexf

# %%
# !git add /content/MyDrive/Colab Notebooks/Nexf_task2.ipynb
# Out:
# fatal: Invalid path '/content/MyDrive': No such file or directory
